# %% [markdown]
# ## Reading and Understanding Data
# ##### -	X1 Relative Compactness
# ##### -	X2 Surface Area
# ##### -	X3 Wall Area
# ##### -	X4 Roof Area
# ##### -	X5 Overall Height
# ##### -	X6 Orientation
# ##### -	X7 Glazing Area
# ##### -	X8 Glazing Area Distribution
# ##### -	y1 Heating Load
# ##### -	y2 Cooling Load

# %%
# File location and type
file_location = "/FileStore/tables/ENB2012_data-1.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
dbf = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(dbf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>X1</th><th>X2</th><th>X3</th><th>X4</th><th>X5</th><th>X6</th><th>X7</th><th>X8</th><th>Y1</th><th>Y2</th></tr></thead><tbody><tr><td>0.98</td><td>514.50</td><td>294.00</td><td>110.25</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>15.55</td><td>21.33</td></tr><tr><td>0.98</td><td>514.50</td><td>294.00</td><td>110.25</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>15.55</td><td>21.33</td></tr><tr><td>0.98</td><td>514.50</td><td>294.00</td><td>110.25</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>15.55</td><td>21.33</td></tr><tr><td>0.98</td><td>514.50</td><td>294.00</td><td>110.25</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>15.55</td><td>21.33</td></tr><tr><td>0.90</td><td>563.50</td><td>318.50</td><td>122.50</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>20.84</td><td>28.28</td></tr><tr><td>0.90</td><td>563.50</td><td>318.50</td><td>122.50</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>21.46</td><td>25.38</td></tr><tr><td>0.90</td><td>563.50</td><td>318.50</td><td>122.50</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>20.71</td><td>25.16</td></tr><tr><td>0.90</td><td>563.50</td><td>318.50</td><td>122.50</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>19.68</td><td>29.60</td></tr><tr><td>0.86</td><td>588.00</td><td>294.00</td><td>147.00</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>19.50</td><td>27.30</td></tr><tr><td>0.86</td><td>588.00</td><td>294.00</td><td>147.00</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>19.95</td><td>21.97</td></tr><tr><td>0.86</td><td>588.00</td><td>294.00</td><td>147.00</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>19.34</td><td>23.49</td></tr><tr><td>0.86</td><td>588.00</td><td>294.00</td><td>147.00</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>18.31</td><td>27.87</td></tr><tr><td>0.82</td><td>612.50</td><td>318.50</td><td>147.00</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>17.05</td><td>23.77</td></tr><tr><td>0.82</td><td>612.50</td><td>318.50</td><td>147.00</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>17.41</td><td>21.46</td></tr><tr><td>0.82</td><td>612.50</td><td>318.50</td><td>147.00</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>16.95</td><td>21.16</td></tr><tr><td>0.82</td><td>612.50</td><td>318.50</td><td>147.00</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>15.98</td><td>24.93</td></tr><tr><td>0.79</td><td>637.00</td><td>343.00</td><td>147.00</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>28.52</td><td>37.73</td></tr><tr><td>0.79</td><td>637.00</td><td>343.00</td><td>147.00</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>29.90</td><td>31.27</td></tr><tr><td>0.79</td><td>637.00</td><td>343.00</td><td>147.00</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>29.63</td><td>30.93</td></tr><tr><td>0.79</td><td>637.00</td><td>343.00</td><td>147.00</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>28.75</td><td>39.44</td></tr><tr><td>0.76</td><td>661.50</td><td>416.50</td><td>122.50</td><td>7.00</td><td>2</td><td>0.00</td><td>0</td><td>24.77</td><td>29.79</td></tr><tr><td>0.76</td><td>661.50</td><td>416.50</td><td>122.50</td><td>7.00</td><td>3</td><td>0.00</td><td>0</td><td>23.93</td><td>29.68</td></tr><tr><td>0.76</td><td>661.50</td><td>416.50</td><td>122.50</td><td>7.00</td><td>4</td><td>0.00</td><td>0</td><td>24.77</td><td>29.79</td></tr><tr><td>0.76</td><td>661.50</td><td>416.50</td><td>122.50</td><td>7.00</td><td>5</td><td>0.00</td><td>0</td><td>23.93</td><td>29.40</td></tr><tr><td>0.74</td><td>686.00</td><td>245.00</td><td>220.50</td><td>3.50</td><td>2</td><td>0.00</td><td>0</td><td>6.07</td><td>10.90</td></tr><tr><td>0.74</td><td>686.00</td><td>245.00</td><td>220.50</td><td>3.50</td><td>3</td><td>0.00</td><td>0</td><td>6.05</td><td>11.19</td></tr><tr><td>0.74</td><td>686.00</td><td>245.00</td><td>220.50</td><td>3.50</td><td>4</td><td>0. ...

# %%
# import required libraries for clustering
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %% [markdown]
# ##### 1 Convert Data from Spark to Pandas DataFrame
# ##### 2 Rename column names to meaningfull names
# ##### 3 Convert column data types to original datatypes

# %%
# Convert Spark DataFrame to Pandas DataFrame
df = dbf.toPandas()

#Rename the columns
df.rename(columns={'X1':'Relative_Compactness','X2':'Surface_Area',
                   'X3':'Wall_Area','X4':'Roof_Area','X5':'Overall_Height',
                   'X6':'Orientation','X7':'Glazing_Area',
                   'X8':'Glazing_Area_Distribution','Y1':'Heating_Load',
                   'Y2':'Cooling_Load'}, inplace=True)

df
# Out:
#     Relative_Compactness Surface_Area  ... Heating_Load Cooling_Load
# 0                   0.98       514.50  ...        15.55        21.33
# 1                   0.98       514.50  ...        15.55        21.33
# 2                   0.98       514.50  ...        15.55        21.33
# 3                   0.98       514.50  ...        15.55        21.33
# 4                   0.90       563.50  ...        20.84        28.28
# ..                   ...          ...  ...          ...          ...
# 763                 0.64       784.00  ...        17.88        21.40
# 764                 0.62       808.50  ...        16.54        16.88
# 765                 0.62       808.50  ...        16.44        17.11
# 766                 0.62       808.50  ...        16.48        16.61
# 767                 0.62       808.50  ...        16.64        16.03
#
# [768 rows x 10 columns]

# %%
# Convert data types of specific columns
df = df.astype({
    'Relative_Compactness': 'float64',
    'Surface_Area': 'float64',
    'Wall_Area': 'float64',
    'Roof_Area': 'float64',
    'Overall_Height': 'float64',
    'Orientation': 'int64',
    'Glazing_Area': 'float64',
    'Glazing_Area_Distribution': 'int64',
    'Heating_Load': 'float64',
    'Cooling_Load': 'float64'
})

# Verify the changes
print(df.dtypes)
# Out:
# Relative_Compactness         float64
# Surface_Area                 float64
# Wall_Area                    float64
# Roof_Area                    float64
# Overall_Height               float64
# Orientation                    int64
# Glazing_Area                 float64
# Glazing_Area_Distribution      int64
# Heating_Load                 float64
# Cooling_Load                 float64
# dtype: object

# %% [markdown]
# Data Exploring

# %%
print(df.shape)
# Out:
# (768, 10)

# %%
print(df.isnull().sum())
# Out:
# Relative_Compactness         0
# Surface_Area                 0
# Wall_Area                    0
# Roof_Area                    0
# Overall_Height               0
# Orientation                  0
# Glazing_Area                 0
# Glazing_Area_Distribution    0
# Heating_Load                 0
# Cooling_Load                 0
# dtype: int64

# %%
df.describe([0, 0.05, 0.50, 0.95, 0.99, 1]).T
# Out:
#                            count        mean  ...    100%     max
# Relative_Compactness       768.0    0.764167  ...    0.98    0.98
# Surface_Area               768.0  671.708333  ...  808.50  808.50
# Wall_Area                  768.0  318.500000  ...  416.50  416.50
# Roof_Area                  768.0  176.604167  ...  220.50  220.50
# Overall_Height             768.0    5.250000  ...    7.00    7.00
# Orientation                768.0    3.500000  ...    5.00    5.00
# Glazing_Area               768.0    0.234375  ...    0.40    0.40
# Glazing_Area_Distribution  768.0    2.812500  ...    5.00    5.00
# Heating_Load               768.0   22.307201  ...   43.10   43.10
# Cooling_Load               768.0   24.587760  ...   48.03   48.03
#
# [10 rows x 11 columns]

# %%
# categorise based on column types
def grab_col_names(dataframe, cat_th=15, car_th=20):
    #Catgeorical Variable Selection
    cat_cols = [col for col in dataframe.columns if str(dataframe[col].dtypes) in ["category","object","bool"]]
    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and dataframe[col].dtypes in ["uint8","int64","float64"]]
    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and str(dataframe[col].dtypes) in ["category","object"]]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    #Numerical Variable Selection
    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes in ["uint8","int64","float64"]]
    num_cols = [col for col in num_cols if col not in cat_cols]

    return cat_cols, num_cols, cat_but_car, num_but_cat

cat_cols, num_cols, cat_but_car, num_but_cat = grab_col_names(df)

# %%
def cat_summary(dataframe,col_name,plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                      'Ration': 100 * dataframe[col_name].value_counts() / len(dataframe)}))
    if plot:
        sns.countplot(x=dataframe[col_name],data=dataframe)
        plt.show(block=True)

# %%
def cat_summary_df(dataframe):
    cat_cols, num_cols, cat_but_car, num_but_cat = grab_col_names(df)
    for col in cat_cols:
        cat_summary(dataframe, col, plot=True)

# %%
cat_summary_df(df)
# Out:
#       Relative_Compactness    Ration
# 0.98                    64  8.333333
# 0.90                    64  8.333333
# 0.86                    64  8.333333
# 0.82                    64  8.333333
# 0.79                    64  8.333333
# 0.76                    64  8.333333
# 0.74                    64  8.333333
# 0.71                    64  8.333333
# 0.69                    64  8.333333
# 0.66                    64  8.333333
# 0.64                    64  8.333333
# 0.62                    64  8.333333
#        Surface_Area    Ration
# 514.5            64  8.333333
# 563.5            64  8.333333
# 588.0            64  8.333333
# 612.5            64  8.333333
# 637.0            64  8.333333
# 661.5            64  8.333333
# 686.0            64  8.333333
# 710.5            64  8.333333
# 735.0            64  8.333333
# 759.5            64  8.333333
# 784.0            64  8.333333
# 808.5            64  8.333333
#        Wall_Area     Ration
# 294.0        192  25.000000
# 318.5        192  25.000000
# 343.0        128  16.666667
# 416.5         64   8.333333
# 245.0         64   8.333333
# 269.5         64   8.333333
# 367.5         64   8.333333
#         Roof_Area     Ration
# 220.50        384  50.000000
# 147.00        192  25.000000
# 122.50        128  16.666667
# 110.25         64   8.333333
#      Overall_Height  Ration
# 7.0             384    50.0
# 3.5             384    50.0
#    Orientation  Ration
# 2          192    25.0
# 3          192    25.0
# 4          192    25.0
# 5          192    25.0
#       Glazing_Area  Ration
# 0.10           240   31.25
# 0.25           240   31.25
# 0.40           240   31.25
# 0.00            48    6.25
#    Glazing_Area_Distribution  Ration
# 1                        144   18.75
# 2                        144   18.75
# 3                        144   18.75
# 4                        144   18.75
# 5                        144   18.75
# 0                         48    6.25

# %% [markdown]
# Analysis of Categorical and Numerical Variables

# %%
def plot_num_summary(dataframe):
    cat_cols, num_cols, cat_but_car, num_but_cat = grab_col_names(dataframe)
    plt.figure(figsize=(10,4))
    for index, col in enumerate(num_cols):
        plt.subplot(1,2,index+1)
        plt.tight_layout()
        dataframe[col].hist(bins=20)
        plt.title(col)
        
plot_num_summary(df)
# Out:
# /root/.ipykernel/5280/command-3178850420648-91922312:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# Examination of the dependent variable

# %%
def exam_dependent_variable(dataframe, target):
    plt.figure(figsize=(16,4))
    plt.subplot(121)
    dataframe[target].hist(bins=100)
    plt.title(target + ", Histogram")
    plt.subplot(122)
    np.log1p(dataframe[target]).hist(bins=50)
    plt.title(target + ", Logaritmic Histogram")

exam_dependent_variable(df, "Heating_Load")

# %%
exam_dependent_variable(df, "Cooling_Load")

# %% [markdown]
# Correlation Analysis

# %%
df.corr()
# Out:
#                            Relative_Compactness  ...  Cooling_Load
# Relative_Compactness               1.000000e+00  ...      0.634339
# Surface_Area                      -9.919015e-01  ...     -0.672999
# Wall_Area                         -2.037817e-01  ...      0.427117
# Roof_Area                         -8.688234e-01  ...     -0.862547
# Overall_Height                     8.277473e-01  ...      0.895785
# Orientation                        4.678592e-17  ...      0.014290
# Glazing_Area                      -2.960552e-15  ...      0.207505
# Glazing_Area_Distribution         -7.107006e-16  ...      0.050525
# Heating_Load                       6.222722e-01  ...      0.975862
# Cooling_Load                       6.343391e-01  ...      1.000000
#
# [10 rows x 10 columns]

# %%
f, ax = plt.subplots(figsize=[18, 13])
sns.heatmap(df.corr(), annot=True, fmt=".2f", ax=ax, cmap="magma")
ax.set_title("Correlation Matrix", fontsize=20)
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Input, Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Functions for formatting output and normalizing data
def format_output(data):
    y1 = data.pop('Heating_Load')
    y1 = np.array(y1)
    y2 = data.pop('Cooling_Load')
    y2 = np.array(y2)
    return y1, y2

def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
# Convert output arrays to dictionary format for Keras model
train_Y = {'y1_output': train_Y[0], 'y2_output': train_Y[1]}
test_Y = {'y1_output': test_Y[0], 'y2_output': test_Y[1]}

# Define model layers
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units=128, activation='relu')(input_layer)
second_dense = Dense(units=128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units=1, name='y1_output')(second_dense)
third_dense = Dense(units=64, activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units=1, name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

# Print the model summary
print(model.summary())
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │      1,152 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │     16,512 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      8,256 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │        129 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         65 │ dense_6[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,114 (102.01 KB)
#  Trainable params: 26,114 (102.01 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Compile the model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# Train the model
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))

# Test the model and print loss and mse for both outputs
results = model.evaluate(x=norm_test_X, y=test_Y)

# Print the results to see what is returned
print("Evaluation Results:", results)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 512.1418 - y1_output_root_mean_squared_error: 15.0160 - y2_output_root_mean_squared_error: 15.8289
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 498.1264 - y1_output_root_mean_squared_error: 14.7826 - y2_output_root_mean_squared_error: 15.5891 - val_loss: 132.6368 - val_y1_output_root_mean_squared_error: 6.4267 - val_y2_output_root_mean_squared_error: 9.3237
# Epoch 2/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.8076 - y1_output_root_mean_squared_error: 4.0933 - y2_output_root_mean_squared_error: 5.7371
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 50.0085 - y1_output_root_mean_squared_error: 4.0364 - y2_output_root_mean_squared_error: 5.6311 - val_loss: 29.6896 - val_y1_output_root_mean_squared_error: 3.7444 - val_y2_output_root_mean_squared_error: 3.7351
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.5837 - y1_output_root_mean_squared_error: 3.1756 - y2_output_root_mean_squared_error: 3.7846 - val_loss: 70.1905 - val_y1_output_root_mean_squared_error: 4.3505 - val_y2_output_root_mean_squared_error: 6.8667
# Epoch 4/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.1940 - y1_output_root_mean_squared_error: 3.3906 - y2_output_root_mean_squared_error: 4.7051
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 33.0340 - y1_output_root_mean_squared_error: 3.3528 - y2_output_root_mean_squared_error: 4.6144 - val_loss: 26.5514 - val_y1_output_root_mean_squared_error: 3.3085 - val_y2_output_root_mean_squared_error: 3.7350
# Epoch 5/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.2905 - y1_output_root_mean_squared_error: 2.9333 - y2_output_root_mean_squared_error: 3.5384
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 21.4773 - y1_output_root_mean_squared_error: 2.9417 - y2_output_root_mean_squared_error: 3.5606 - val_loss: 23.5671 - val_y1_output_root_mean_squared_error: 3.1122 - val_y2_output_root_mean_squared_error: 3.5775
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.6322 - y1_output_root_mean_squared_error: 3.0359 - y2_output_root_mean_squared_error: 3.8898 - val_loss: 65.5545 - val_y1_output_root_mean_squared_error: 3.5430 - val_y2_output_root_mean_squared_error: 7.1415
# Epoch 7/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0588 - y1_output_root_mean_squared_error: 3.1164 - y2_output_root_mean_squared_error: 4.4528
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 29.6311 - y1_output_root_mean_squared_error: 3.1119 - y2_output_root_mean_squared_error: 4.4151 - val_loss: 56.1493 - val_y1_output_root_mean_squared_error: 3.9771 - val_y2_output_root_mean_squared_error: 6.1688
# Epoch 8/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.5210 - y1_output_root_mean_squared_error: 3.0870 - y2_output_root_mean_squared_error: 4.3221
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 27.8999 - y1_output_root_mean_squared_error: 3.0624 - y2_output_root_mean_squared_error: 4.2709 - val_loss: 23.9522 - val_y1_output_root_mean_squared_error: 3.1014 - val_y2_output_root_mean_squared_error: 3.6656
# Epoch 9/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.9403 - y1_output_root_mean_squared_error: 2.9997 - y2_output_root_mean_squared_error: 3.5608
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 22.1437 - y1_output_root_mean_squared_error: 3.0042 - y2_output_root_mean_squared_error: 3.5860 - val_loss: 22.3239 - val_y1_output_root_mean_squared_error: 3.3381 - val_y2_output_root_mean_squared_error: 3.1377
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.7025 - y1_output_root_mean_squared_error: 2.6190 - y2_output_root_mean_squared_error: 3.4026 - val_loss: 177.8626 - val_y1_output_root_mean_squared_error: 7.4160 - val_y2_output_root_mean_squared_error: 10.8526
# Epoch 11/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.9812 - y1_output_root_mean_squared_error: 3.0649 - y2_output_root_mean_squared_error: 4.3361
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 28.3921 - y1_output_root_mean_squared_error: 3.0455 - y2_output_root_mean_squared_error: 4.2879 - val_loss: 39.8864 - val_y1_output_root_mean_squared_error: 3.3624 - val_y2_output_root_mean_squared_error: 5.1587
# Epoch 12/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.3223 - y1_output_root_mean_squared_error: 2.6715 - y2_output_root_mean_squared_error: 3.9342
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 23.2474 - y1_output_root_mean_squared_error: 2.6765 - y2_output_root_mean_squared_error: 3.9248 - val_loss: 22.2616 - val_y1_output_root_mean_squared_error: 3.0475 - val_y2_output_root_mean_squared_error: 3.3988
# Epoch 13/500
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.2053 - y1_output_root_mean_squared_error: 2.8841 - y2_output_root_mean_squared_error: 3.4323
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 20.3563 - y1_output_root_mean_squared_error: 2.8795 - y2_output_root_mean_squared_error: 3.4586 - val_loss: 19.3340 - val_y1_output_root_mean_squared_error: 2.9128 - val_y2_output_root_mean_squared_error: 3.1534
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.4140 - y1_output_root_mean_squared_error: 2.9000 - y2_output_root_mean_squared_error: 3.8454 - val_loss: 23.1055 - val_y1_output_root_mean_squared_error: 3.0705 - val_y2_output_root_mean_squared_error: 3.5214
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.1924 - y1_output_root_mean_squared_error: 2.7602 - y2_output_root_mean_squared_error: 3.3909 - val_loss: 59.4361 - val_y1_output_root_mean_squared_error: 3.5012 - val_y2_output_root_mean_squared_error: 6.5910
# Epoch 16/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9958 - y1_output_root_mean_squared_error: 2.7818 - y2_output_root_mean_squared_error: 3.3379
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 18.9711 - y1_output_root_mean_squared_error: 2.7634 - y2_output_root_mean_squared_error: 3.3526 - val_loss: 15.9670 - val_y1_output_root_mean_squared_error: 2.6429 - val_y2_output_root_mean_squared_error: 2.8228
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4683 - y1_output_root_mean_squared_error: 2.5097 - y2_output_root_mean_squared_error: 3.3281 - val_loss: 36.2466 - val_y1_output_root_mean_squared_error: 3.5424 - val_y2_output_root_mean_squared_error: 4.6507
# Epoch 18/500
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.5937 - y1_output_root_mean_squared_error: 2.5863 - y2_output_root_mean_squared_error: 3.5244
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 19.3091 - y1_output_root_mean_squared_error: 2.5788 - y2_output_root_mean_squared_error: 3.4964 - val_loss: 15.3341 - val_y1_output_root_mean_squared_error: 2.5803 - val_y2_output_root_mean_squared_error: 2.7677
# Epoch 19/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.2396 - y1_output_root_mean_squared_error: 2.5416 - y2_output_root_mean_squared_error: 3.1170
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 16.1864 - y1_output_root_mean_squared_error: 2.5384 - y2_output_root_mean_squared_error: 3.1120 - val_loss: 14.9866 - val_y1_output_root_mean_squared_error: 2.5220 - val_y2_output_root_mean_squared_error: 2.7621
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.7807 - y1_output_root_mean_squared_error: 2.3307 - y2_output_root_mean_squared_error: 3.0469 - val_loss: 15.0944 - val_y1_output_root_mean_squared_error: 2.5100 - val_y2_output_root_mean_squared_error: 2.7857
# Epoch 21/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.9589 - y1_output_root_mean_squared_error: 2.5123 - y2_output_root_mean_squared_error: 3.2471
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 16.7921 - y1_output_root_mean_squared_error: 2.5043 - y2_output_root_mean_squared_error: 3.2294 - val_loss: 13.9548 - val_y1_output_root_mean_squared_error: 2.3870 - val_y2_output_root_mean_squared_error: 2.6887
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.9801 - y1_output_root_mean_squared_error: 2.4621 - y2_output_root_mean_squared_error: 3.2947 - val_loss: 83.5340 - val_y1_output_root_mean_squared_error: 4.0290 - val_y2_output_root_mean_squared_error: 7.9431
# Epoch 23/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.9439 - y1_output_root_mean_squared_error: 2.8303 - y2_output_root_mean_squared_error: 4.4552
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 29.3819 - y1_output_root_mean_squared_error: 2.8138 - y2_output_root_mean_squared_error: 4.4079 - val_loss: 21.9023 - val_y1_output_root_mean_squared_error: 2.7303 - val_y2_output_root_mean_squared_error: 3.5679
# Epoch 24/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7791 - y1_output_root_mean_squared_error: 2.4839 - y2_output_root_mean_squared_error: 3.5268
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 18.7216 - y1_output_root_mean_squared_error: 2.4839 - y2_output_root_mean_squared_error: 3.5220 - val_loss: 16.7031 - val_y1_output_root_mean_squared_error: 2.5230 - val_y2_output_root_mean_squared_error: 3.0879
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.4302 - y1_output_root_mean_squared_error: 2.2811 - y2_output_root_mean_squared_error: 2.8479 - val_loss: 26.8042 - val_y1_output_root_mean_squared_error: 3.0322 - val_y2_output_root_mean_squared_error: 4.0884
# Epoch 26/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.1710 - y1_output_root_mean_squared_error: 2.3453 - y2_output_root_mean_squared_error: 2.9191
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 14.4993 - y1_output_root_mean_squared_error: 2.3704 - y2_output_root_mean_squared_error: 2.9573 - val_loss: 20.6965 - val_y1_output_root_mean_squared_error: 2.6499 - val_y2_output_root_mean_squared_error: 3.5158
# Epoch 27/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4036 - y1_output_root_mean_squared_error: 2.2624 - y2_output_root_mean_squared_error: 2.8730
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 13.4122 - y1_output_root_mean_squared_error: 2.2627 - y2_output_root_mean_squared_error: 2.8752 - val_loss: 14.2489 - val_y1_output_root_mean_squared_error: 2.3507 - val_y2_output_root_mean_squared_error: 2.7624
# Epoch 28/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.2879 - y1_output_root_mean_squared_error: 2.0188 - y2_output_root_mean_squared_error: 2.8399
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 12.3760 - y1_output_root_mean_squared_error: 2.0292 - y2_output_root_mean_squared_error: 2.8491 - val_loss: 12.5350 - val_y1_output_root_mean_squared_error: 2.3199 - val_y2_output_root_mean_squared_error: 2.5300
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.0345 - y1_output_root_mean_squared_error: 2.2959 - y2_output_root_mean_squared_error: 2.7783 - val_loss: 13.0691 - val_y1_output_root_mean_squared_error: 2.1867 - val_y2_output_root_mean_squared_error: 2.6828
# Epoch 30/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9061 - y1_output_root_mean_squared_error: 2.3654 - y2_output_root_mean_squared_error: 3.4996
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 17.5465 - y1_output_root_mean_squared_error: 2.3526 - y2_output_root_mean_squared_error: 3.4574 - val_loss: 11.3485 - val_y1_output_root_mean_squared_error: 2.2028 - val_y2_output_root_mean_squared_error: 2.4109
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.0087 - y1_output_root_mean_squared_error: 1.9590 - y2_output_root_mean_squared_error: 2.6698 - val_loss: 88.2520 - val_y1_output_root_mean_squared_error: 5.1346 - val_y2_output_root_mean_squared_error: 7.7632
# Epoch 32/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1383 - y1_output_root_mean_squared_error: 2.5120 - y2_output_root_mean_squared_error: 3.2056
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 16.6987 - y1_output_root_mean_squared_error: 2.4790 - y2_output_root_mean_squared_error: 3.1674 - val_loss: 11.6171 - val_y1_output_root_mean_squared_error: 2.1541 - val_y2_output_root_mean_squared_error: 2.4747
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.9536 - y1_output_root_mean_squared_error: 2.3272 - y2_output_root_mean_squared_error: 2.9073 - val_loss: 19.5292 - val_y1_output_root_mean_squared_error: 2.8311 - val_y2_output_root_mean_squared_error: 3.3074
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 15.7995 - y1_output_root_mean_squared_error: 2.2660 - y2_output_root_mean_squared_error: 3.2430
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 15.7650 - y1_output_root_mean_squared_error: 2.2645 - y2_output_root_mean_squared_error: 3.2392 - val_loss: 13.0668 - val_y1_output_root_mean_squared_error: 2.1941 - val_y2_output_root_mean_squared_error: 2.7862
# Epoch 35/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4217 - y1_output_root_mean_squared_error: 2.1621 - y2_output_root_mean_squared_error: 2.7758
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 12.4190 - y1_output_root_mean_squared_error: 2.1564 - y2_output_root_mean_squared_error: 2.7805 - val_loss: 9.8286 - val_y1_output_root_mean_squared_error: 1.9598 - val_y2_output_root_mean_squared_error: 2.3235
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4036 - y1_output_root_mean_squared_error: 1.9258 - y2_output_root_mean_squared_error: 2.5828 - val_loss: 12.7785 - val_y1_output_root_mean_squared_error: 1.9617 - val_y2_output_root_mean_squared_error: 2.8535
# Epoch 37/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5516 - y1_output_root_mean_squared_error: 1.9645 - y2_output_root_mean_squared_error: 2.5754
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 10.5868 - y1_output_root_mean_squared_error: 1.9618 - y2_output_root_mean_squared_error: 2.5863 - val_loss: 9.9002 - val_y1_output_root_mean_squared_error: 1.9652 - val_y2_output_root_mean_squared_error: 2.3377
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 10.3812 - y1_output_root_mean_squared_error: 1.9214 - y2_output_root_mean_squared_error: 2.5657 - val_loss: 27.5774 - val_y1_output_root_mean_squared_error: 3.3053 - val_y2_output_root_mean_squared_error: 4.0387
# Epoch 39/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2923 - y1_output_root_mean_squared_error: 1.9734 - y2_output_root_mean_squared_error: 2.6962
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 11.0798 - y1_output_root_mean_squared_error: 1.9613 - y2_output_root_mean_squared_error: 2.6668 - val_loss: 11.0158 - val_y1_output_root_mean_squared_error: 2.2108 - val_y2_output_root_mean_squared_error: 2.3968
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9615 - y1_output_root_mean_squared_error: 1.7377 - y2_output_root_mean_squared_error: 2.2145 - val_loss: 18.5473 - val_y1_output_root_mean_squared_error: 2.2694 - val_y2_output_root_mean_squared_error: 3.5324
# Epoch 41/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0919 - y1_output_root_mean_squared_error: 1.6969 - y2_output_root_mean_squared_error: 2.2713
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3091 - y1_output_root_mean_squared_error: 1.7099 - y2_output_root_mean_squared_error: 2.3088 - val_loss: 8.8079 - val_y1_output_root_mean_squared_error: 1.7195 - val_y2_output_root_mean_squared_error: 2.3049
# Epoch 42/500
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1225 - y1_output_root_mean_squared_error: 1.8060 - y2_output_root_mean_squared_error: 2.4150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.0779 - y1_output_root_mean_squared_error: 1.8017 - y2_output_root_mean_squared_error: 2.4103 - val_loss: 7.6800 - val_y1_output_root_mean_squared_error: 1.6702 - val_y2_output_root_mean_squared_error: 2.1316
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5567 - y1_output_root_mean_squared_error: 1.5829 - y2_output_root_mean_squared_error: 2.2425 - val_loss: 8.8174 - val_y1_output_root_mean_squared_error: 1.7782 - val_y2_output_root_mean_squared_error: 2.2936
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5744 - y1_output_root_mean_squared_error: 1.5472 - y2_output_root_mean_squared_error: 2.0394 - val_loss: 12.4391 - val_y1_output_root_mean_squared_error: 1.8065 - val_y2_output_root_mean_squared_error: 2.9540
# Epoch 45/500
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0008 - y1_output_root_mean_squared_error: 1.6581 - y2_output_root_mean_squared_error: 2.4932
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.9466 - y1_output_root_mean_squared_error: 1.6586 - y2_output_root_mean_squared_error: 2.4830 - val_loss: 12.2104 - val_y1_output_root_mean_squared_error: 1.9676 - val_y2_output_root_mean_squared_error: 2.8526
# Epoch 46/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0805 - y1_output_root_mean_squared_error: 1.6180 - y2_output_root_mean_squared_error: 2.3068
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.1023 - y1_output_root_mean_squared_error: 1.6206 - y2_output_root_mean_squared_error: 2.3102 - val_loss: 12.0801 - val_y1_output_root_mean_squared_error: 1.9813 - val_y2_output_root_mean_squared_error: 2.7749
# Epoch 47/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7046 - y1_output_root_mean_squared_error: 1.6064 - y2_output_root_mean_squared_error: 2.2538
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7242 - y1_output_root_mean_squared_error: 1.6076 - y2_output_root_mean_squared_error: 2.2585 - val_loss: 8.2694 - val_y1_output_root_mean_squared_error: 1.6204 - val_y2_output_root_mean_squared_error: 2.3187
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6354 - y1_output_root_mean_squared_error: 1.6607 - y2_output_root_mean_squared_error: 2.4127 - val_loss: 8.4864 - val_y1_output_root_mean_squared_error: 1.7631 - val_y2_output_root_mean_squared_error: 2.2689
# Epoch 49/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6524 - y1_output_root_mean_squared_error: 1.4761 - y2_output_root_mean_squared_error: 2.1101
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6312 - y1_output_root_mean_squared_error: 1.4745 - y2_output_root_mean_squared_error: 2.1066 - val_loss: 7.3221 - val_y1_output_root_mean_squared_error: 1.7040 - val_y2_output_root_mean_squared_error: 2.0470
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8507 - y1_output_root_mean_squared_error: 1.6313 - y2_output_root_mean_squared_error: 2.2455 - val_loss: 8.8790 - val_y1_output_root_mean_squared_error: 1.5914 - val_y2_output_root_mean_squared_error: 2.4558
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1721 - y1_output_root_mean_squared_error: 1.5029 - y2_output_root_mean_squared_error: 2.2104 - val_loss: 11.1918 - val_y1_output_root_mean_squared_error: 1.6954 - val_y2_output_root_mean_squared_error: 2.8322
# Epoch 52/500
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5960 - y1_output_root_mean_squared_error: 1.4518 - y2_output_root_mean_squared_error: 1.8603
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6633 - y1_output_root_mean_squared_error: 1.4558 - y2_output_root_mean_squared_error: 1.8763 - val_loss: 7.1150 - val_y1_output_root_mean_squared_error: 1.4425 - val_y2_output_root_mean_squared_error: 2.1979
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1622 - y1_output_root_mean_squared_error: 1.5266 - y2_output_root_mean_squared_error: 2.1880 - val_loss: 10.0747 - val_y1_output_root_mean_squared_error: 1.7446 - val_y2_output_root_mean_squared_error: 2.5825
# Epoch 54/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1694 - y1_output_root_mean_squared_error: 1.5233 - y2_output_root_mean_squared_error: 1.9563
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1823 - y1_output_root_mean_squared_error: 1.5136 - y2_output_root_mean_squared_error: 1.9675 - val_loss: 8.3479 - val_y1_output_root_mean_squared_error: 1.7482 - val_y2_output_root_mean_squared_error: 2.2601
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.7873 - y1_output_root_mean_squared_error: 1.4582 - y2_output_root_mean_squared_error: 2.3446 - val_loss: 10.9265 - val_y1_output_root_mean_squared_error: 2.1008 - val_y2_output_root_mean_squared_error: 2.4854
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8750 - y1_output_root_mean_squared_error: 1.4124 - y2_output_root_mean_squared_error: 1.9646 - val_loss: 16.5176 - val_y1_output_root_mean_squared_error: 1.7745 - val_y2_output_root_mean_squared_error: 3.6171
# Epoch 57/500
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3911 - y1_output_root_mean_squared_error: 1.4692 - y2_output_root_mean_squared_error: 2.2563
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.2938 - y1_output_root_mean_squared_error: 1.4678 - y2_output_root_mean_squared_error: 2.2407 - val_loss: 7.5228 - val_y1_output_root_mean_squared_error: 1.4866 - val_y2_output_root_mean_squared_error: 2.2359
# Epoch 58/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3475 - y1_output_root_mean_squared_error: 1.3265 - y2_output_root_mean_squared_error: 1.8885
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3509 - y1_output_root_mean_squared_error: 1.3275 - y2_output_root_mean_squared_error: 1.8894 - val_loss: 5.5909 - val_y1_output_root_mean_squared_error: 1.3755 - val_y2_output_root_mean_squared_error: 1.8791
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0339 - y1_output_root_mean_squared_error: 1.2774 - y2_output_root_mean_squared_error: 1.8431 - val_loss: 5.8257 - val_y1_output_root_mean_squared_error: 1.3552 - val_y2_output_root_mean_squared_error: 1.9540
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0701 - y1_output_root_mean_squared_error: 1.3855 - y2_output_root_mean_squared_error: 2.0329 - val_loss: 10.5177 - val_y1_output_root_mean_squared_error: 2.2329 - val_y2_output_root_mean_squared_error: 2.3073
# Epoch 61/500
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2934 - y1_output_root_mean_squared_error: 1.4158 - y2_output_root_mean_squared_error: 2.0601
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.1540 - y1_output_root_mean_squared_error: 1.3958 - y2_output_root_mean_squared_error: 2.0409 - val_loss: 5.5805 - val_y1_output_root_mean_squared_error: 1.4033 - val_y2_output_root_mean_squared_error: 1.8526
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8138 - y1_output_root_mean_squared_error: 1.2715 - y2_output_root_mean_squared_error: 1.7852 - val_loss: 8.3062 - val_y1_output_root_mean_squared_error: 1.3427 - val_y2_output_root_mean_squared_error: 2.4952
# Epoch 63/500
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8199 - y1_output_root_mean_squared_error: 1.4464 - y2_output_root_mean_squared_error: 2.1598
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.6848 - y1_output_root_mean_squared_error: 1.4375 - y2_output_root_mean_squared_error: 2.1362 - val_loss: 5.3423 - val_y1_output_root_mean_squared_error: 1.3448 - val_y2_output_root_mean_squared_error: 1.8195
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2035 - y1_output_root_mean_squared_error: 1.1982 - y2_output_root_mean_squared_error: 1.6504 - val_loss: 8.0353 - val_y1_output_root_mean_squared_error: 1.7519 - val_y2_output_root_mean_squared_error: 2.1464
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0161 - y1_output_root_mean_squared_error: 1.4288 - y2_output_root_mean_squared_error: 1.9844 - val_loss: 15.6067 - val_y1_output_root_mean_squared_error: 2.4600 - val_y2_output_root_mean_squared_error: 2.9953
# Epoch 66/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3197 - y1_output_root_mean_squared_error: 1.5470 - y2_output_root_mean_squared_error: 2.1575
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.9514 - y1_output_root_mean_squared_error: 1.5017 - y2_output_root_mean_squared_error: 2.1103 - val_loss: 5.0916 - val_y1_output_root_mean_squared_error: 1.2296 - val_y2_output_root_mean_squared_error: 1.8567
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1871 - y1_output_root_mean_squared_error: 1.3985 - y2_output_root_mean_squared_error: 2.2653 - val_loss: 6.3203 - val_y1_output_root_mean_squared_error: 1.3009 - val_y2_output_root_mean_squared_error: 2.0911
# Epoch 68/500
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8105 - y1_output_root_mean_squared_error: 1.1742 - y2_output_root_mean_squared_error: 1.8473
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8129 - y1_output_root_mean_squared_error: 1.1747 - y2_output_root_mean_squared_error: 1.8482 - val_loss: 5.3063 - val_y1_output_root_mean_squared_error: 1.2184 - val_y2_output_root_mean_squared_error: 1.9215
# Epoch 69/500
# 51/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2377 - y1_output_root_mean_squared_error: 1.1197 - y2_output_root_mean_squared_error: 1.7216
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3999 - y1_output_root_mean_squared_error: 1.1388 - y2_output_root_mean_squared_error: 1.7552 - val_loss: 5.2423 - val_y1_output_root_mean_squared_error: 1.2502 - val_y2_output_root_mean_squared_error: 1.8916
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7490 - y1_output_root_mean_squared_error: 1.3022 - y2_output_root_mean_squared_error: 2.0026 - val_loss: 5.9426 - val_y1_output_root_mean_squared_error: 1.4571 - val_y2_output_root_mean_squared_error: 1.9290
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.3137 - y1_output_root_mean_squared_error: 1.2209 - y2_output_root_mean_squared_error: 1.6707 - val_loss: 9.6678 - val_y1_output_root_mean_squared_error: 1.9280 - val_y2_output_root_mean_squared_error: 2.4091
# Epoch 72/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6381 - y1_output_root_mean_squared_error: 1.2243 - y2_output_root_mean_squared_error: 1.7646
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.6817 - y1_output_root_mean_squared_error: 1.2221 - y2_output_root_mean_squared_error: 1.7793 - val_loss: 5.9010 - val_y1_output_root_mean_squared_error: 1.3864 - val_y2_output_root_mean_squared_error: 1.9583
# Epoch 73/500
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1563 - y1_output_root_mean_squared_error: 0.9841 - y2_output_root_mean_squared_error: 1.7756
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1502 - y1_output_root_mean_squared_error: 0.9897 - y2_output_root_mean_squared_error: 1.7716 - val_loss: 5.6786 - val_y1_output_root_mean_squared_error: 1.1805 - val_y2_output_root_mean_squared_error: 2.0409
# Epoch 74/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7916 - y1_output_root_mean_squared_error: 1.1432 - y2_output_root_mean_squared_error: 1.8458
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9115 - y1_output_root_mean_squared_error: 1.1584 - y2_output_root_mean_squared_error: 1.8706 - val_loss: 4.3701 - val_y1_output_root_mean_squared_error: 1.0616 - val_y2_output_root_mean_squared_error: 1.7705
# Epoch 75/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8296 - y1_output_root_mean_squared_error: 0.9928 - y2_output_root_mean_squared_error: 1.6824 - val_loss: 4.7794 - val_y1_output_root_mean_squared_error: 1.1632 - val_y2_output_root_mean_squared_error: 1.8076
# Epoch 76/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6173 - y1_output_root_mean_squared_error: 0.9894 - y2_output_root_mean_squared_error: 1.6194 - val_loss: 12.4130 - val_y1_output_root_mean_squared_error: 1.4397 - val_y2_output_root_mean_squared_error: 3.1530
# Epoch 77/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5566 - y1_output_root_mean_squared_error: 1.2787 - y2_output_root_mean_squared_error: 2.1757
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4078 - y1_output_root_mean_squared_error: 1.2658 - y2_output_root_mean_squared_error: 2.1514 - val_loss: 5.2155 - val_y1_output_root_mean_squared_error: 1.4088 - val_y2_output_root_mean_squared_error: 1.7664
# Epoch 78/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5722 - y1_output_root_mean_squared_error: 1.0246 - y2_output_root_mean_squared_error: 1.5740 - val_loss: 5.7780 - val_y1_output_root_mean_squared_error: 1.3028 - val_y2_output_root_mean_squared_error: 1.9844
# Epoch 79/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6919 - y1_output_root_mean_squared_error: 0.9521 - y2_output_root_mean_squared_error: 1.6647 - val_loss: 6.8476 - val_y1_output_root_mean_squared_error: 1.1270 - val_y2_output_root_mean_squared_error: 2.3136
# Epoch 80/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8798 - y1_output_root_mean_squared_error: 1.0616 - y2_output_root_mean_squared_error: 1.6513
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9150 - y1_output_root_mean_squared_error: 1.0574 - y2_output_root_mean_squared_error: 1.6651 - val_loss: 4.4371 - val_y1_output_root_mean_squared_error: 0.9331 - val_y2_output_root_mean_squared_error: 1.8524
# Epoch 81/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4540 - y1_output_root_mean_squared_error: 1.0338 - y2_output_root_mean_squared_error: 1.8197 - val_loss: 7.1923 - val_y1_output_root_mean_squared_error: 1.4728 - val_y2_output_root_mean_squared_error: 2.2274
# Epoch 82/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6376 - y1_output_root_mean_squared_error: 1.1377 - y2_output_root_mean_squared_error: 1.8148
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4632 - y1_output_root_mean_squared_error: 1.1088 - y2_output_root_mean_squared_error: 1.7847 - val_loss: 4.1125 - val_y1_output_root_mean_squared_error: 0.9386 - val_y2_output_root_mean_squared_error: 1.7693
# Epoch 83/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0931 - y1_output_root_mean_squared_error: 0.9960 - y2_output_root_mean_squared_error: 1.7422 - val_loss: 6.3209 - val_y1_output_root_mean_squared_error: 1.3416 - val_y2_output_root_mean_squared_error: 2.1095
# Epoch 84/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7130 - y1_output_root_mean_squared_error: 1.0035 - y2_output_root_mean_squared_error: 1.6292
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7258 - y1_output_root_mean_squared_error: 1.0052 - y2_output_root_mean_squared_error: 1.6323 - val_loss: 3.3770 - val_y1_output_root_mean_squared_error: 0.8780 - val_y2_output_root_mean_squared_error: 1.5875
# Epoch 85/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6720 - y1_output_root_mean_squared_error: 0.8244 - y2_output_root_mean_squared_error: 1.4011 - val_loss: 7.3063 - val_y1_output_root_mean_squared_error: 1.7096 - val_y2_output_root_mean_squared_error: 2.0161
# Epoch 86/500
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0405 - y1_output_root_mean_squared_error: 0.8253 - y2_output_root_mean_squared_error: 1.5288
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.0431 - y1_output_root_mean_squared_error: 0.8262 - y2_output_root_mean_squared_error: 1.5297 - val_loss: 6.0845 - val_y1_output_root_mean_squared_error: 0.9414 - val_y2_output_root_mean_squared_error: 2.2571
# Epoch 87/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6421 - y1_output_root_mean_squared_error: 0.9388 - y2_output_root_mean_squared_error: 1.6214
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7061 - y1_output_root_mean_squared_error: 0.9537 - y2_output_root_mean_squared_error: 1.6360 - val_loss: 4.5550 - val_y1_output_root_mean_squared_error: 0.8782 - val_y2_output_root_mean_squared_error: 1.9018
# Epoch 88/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4379 - y1_output_root_mean_squared_error: 0.8011 - y2_output_root_mean_squared_error: 1.3362
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4616 - y1_output_root_mean_squared_error: 0.8018 - y2_output_root_mean_squared_error: 1.3450 - val_loss: 3.5932 - val_y1_output_root_mean_squared_error: 0.9509 - val_y2_output_root_mean_squared_error: 1.6237
# Epoch 89/500
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7288 - y1_output_root_mean_squared_error: 0.7526 - y2_output_root_mean_squared_error: 1.4570
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7352 - y1_output_root_mean_squared_error: 0.7574 - y2_output_root_mean_squared_error: 1.4579 - val_loss: 3.0003 - val_y1_output_root_mean_squared_error: 0.8281 - val_y2_output_root_mean_squared_error: 1.5081
# Epoch 90/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7923 - y1_output_root_mean_squared_error: 0.7907 - y2_output_root_mean_squared_error: 1.4669 - val_loss: 3.9631 - val_y1_output_root_mean_squared_error: 1.0992 - val_y2_output_root_mean_squared_error: 1.6262
# Epoch 91/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7714 - y1_output_root_mean_squared_error: 1.1536 - y2_output_root_mean_squared_error: 1.5573
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7653 - y1_output_root_mean_squared_error: 1.1515 - y2_output_root_mean_squared_error: 1.5570 - val_loss: 3.1296 - val_y1_output_root_mean_squared_error: 0.8515 - val_y2_output_root_mean_squared_error: 1.5167
# Epoch 92/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1143 - y1_output_root_mean_squared_error: 0.8239 - y2_output_root_mean_squared_error: 1.5514 - val_loss: 10.2326 - val_y1_output_root_mean_squared_error: 1.3451 - val_y2_output_root_mean_squared_error: 2.8098
# Epoch 93/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5856 - y1_output_root_mean_squared_error: 0.9240 - y2_output_root_mean_squared_error: 1.6486
# ...
# Epoch 469/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2723 - y1_output_root_mean_squared_error: 0.2968 - y2_output_root_mean_squared_error: 0.4150 - val_loss: 2.7834 - val_y1_output_root_mean_squared_error: 0.7983 - val_y2_output_root_mean_squared_error: 1.4768
# Epoch 470/500
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5598 - y1_output_root_mean_squared_error: 0.3675 - y2_output_root_mean_squared_error: 0.6404
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5547 - y1_output_root_mean_squared_error: 0.3669 - y2_output_root_mean_squared_error: 0.6369 - val_loss: 0.9621 - val_y1_output_root_mean_squared_error: 0.4588 - val_y2_output_root_mean_squared_error: 0.8792
# Epoch 471/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2930 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.4237 - val_loss: 0.9673 - val_y1_output_root_mean_squared_error: 0.4447 - val_y2_output_root_mean_squared_error: 0.8764
# Epoch 472/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3899 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5196 - val_loss: 1.2248 - val_y1_output_root_mean_squared_error: 0.5814 - val_y2_output_root_mean_squared_error: 0.9455
# Epoch 473/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4020 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.5140
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4021 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.5144 - val_loss: 1.0068 - val_y1_output_root_mean_squared_error: 0.4255 - val_y2_output_root_mean_squared_error: 0.9162
# Epoch 474/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3539 - y1_output_root_mean_squared_error: 0.3129 - y2_output_root_mean_squared_error: 0.5031 - val_loss: 1.0429 - val_y1_output_root_mean_squared_error: 0.4714 - val_y2_output_root_mean_squared_error: 0.9187
# Epoch 475/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4425 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5595 - val_loss: 1.4597 - val_y1_output_root_mean_squared_error: 0.5926 - val_y2_output_root_mean_squared_error: 1.0610
# Epoch 476/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4907 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.6064
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4871 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.6036 - val_loss: 1.1114 - val_y1_output_root_mean_squared_error: 0.5094 - val_y2_output_root_mean_squared_error: 0.9311
# Epoch 477/500
# 55/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4196 - y1_output_root_mean_squared_error: 0.3167 - y2_output_root_mean_squared_error: 0.5632
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4124 - y1_output_root_mean_squared_error: 0.3186 - y2_output_root_mean_squared_error: 0.5556 - val_loss: 1.1010 - val_y1_output_root_mean_squared_error: 0.4506 - val_y2_output_root_mean_squared_error: 0.9433
# Epoch 478/500
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3222 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.4560
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3330 - y1_output_root_mean_squared_error: 0.3276 - y2_output_root_mean_squared_error: 0.4650 - val_loss: 1.0775 - val_y1_output_root_mean_squared_error: 0.4825 - val_y2_output_root_mean_squared_error: 0.9315
# Epoch 479/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2848 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4213
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2834 - y1_output_root_mean_squared_error: 0.3225 - y2_output_root_mean_squared_error: 0.4211 - val_loss: 1.0021 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.9087
# Epoch 480/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3549 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.4772 - val_loss: 1.2247 - val_y1_output_root_mean_squared_error: 0.5671 - val_y2_output_root_mean_squared_error: 0.9589
# Epoch 481/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2815 - y1_output_root_mean_squared_error: 0.3116 - y2_output_root_mean_squared_error: 0.4269
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2820 - y1_output_root_mean_squared_error: 0.3120 - y2_output_root_mean_squared_error: 0.4273 - val_loss: 1.1473 - val_y1_output_root_mean_squared_error: 0.5114 - val_y2_output_root_mean_squared_error: 0.9387
# Epoch 482/500
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2981 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.4188
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2990 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.4205 - val_loss: 0.9590 - val_y1_output_root_mean_squared_error: 0.4027 - val_y2_output_root_mean_squared_error: 0.8919
# Epoch 483/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3549 - y1_output_root_mean_squared_error: 0.3481 - y2_output_root_mean_squared_error: 0.4804 - val_loss: 1.3757 - val_y1_output_root_mean_squared_error: 0.4206 - val_y2_output_root_mean_squared_error: 1.1080
# Epoch 484/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3073 - y1_output_root_mean_squared_error: 0.2973 - y2_output_root_mean_squared_error: 0.4624
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3037 - y1_output_root_mean_squared_error: 0.2995 - y2_output_root_mean_squared_error: 0.4578 - val_loss: 1.1686 - val_y1_output_root_mean_squared_error: 0.5270 - val_y2_output_root_mean_squared_error: 0.9538
# Epoch 485/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3170 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.4572
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3174 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.4577 - val_loss: 1.0221 - val_y1_output_root_mean_squared_error: 0.4537 - val_y2_output_root_mean_squared_error: 0.9136
# Epoch 486/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3103 - y1_output_root_mean_squared_error: 0.3175 - y2_output_root_mean_squared_error: 0.4539 - val_loss: 1.1169 - val_y1_output_root_mean_squared_error: 0.4504 - val_y2_output_root_mean_squared_error: 0.9717
# Epoch 487/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4185 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.5323
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4123 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5283 - val_loss: 0.9120 - val_y1_output_root_mean_squared_error: 0.4362 - val_y2_output_root_mean_squared_error: 0.8585
# Epoch 488/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3245 - y1_output_root_mean_squared_error: 0.3145 - y2_output_root_mean_squared_error: 0.4676 - val_loss: 1.1016 - val_y1_output_root_mean_squared_error: 0.4756 - val_y2_output_root_mean_squared_error: 0.9454
# Epoch 489/500
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3195 - y1_output_root_mean_squared_error: 0.3066 - y2_output_root_mean_squared_error: 0.4726
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3259 - y1_output_root_mean_squared_error: 0.3086 - y2_output_root_mean_squared_error: 0.4781 - val_loss: 0.9104 - val_y1_output_root_mean_squared_error: 0.4069 - val_y2_output_root_mean_squared_error: 0.8671
# Epoch 490/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3466 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.4882 - val_loss: 0.9119 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.8558
# Epoch 491/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3392 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.4732 - val_loss: 1.0164 - val_y1_output_root_mean_squared_error: 0.5039 - val_y2_output_root_mean_squared_error: 0.8748
# Epoch 492/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3219 - y1_output_root_mean_squared_error: 0.3083 - y2_output_root_mean_squared_error: 0.4705 - val_loss: 1.1882 - val_y1_output_root_mean_squared_error: 0.4791 - val_y2_output_root_mean_squared_error: 0.9884
# Epoch 493/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3492 - y1_output_root_mean_squared_error: 0.3402 - y2_output_root_mean_squared_error: 0.4785
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3402 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4708 - val_loss: 1.0021 - val_y1_output_root_mean_squared_error: 0.4101 - val_y2_output_root_mean_squared_error: 0.9230
# Epoch 494/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2357 - y1_output_root_mean_squared_error: 0.3041 - y2_output_root_mean_squared_error: 0.3745 - val_loss: 1.6846 - val_y1_output_root_mean_squared_error: 0.5325 - val_y2_output_root_mean_squared_error: 1.1675
# Epoch 495/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3361 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.4746
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3355 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.4741 - val_loss: 1.0322 - val_y1_output_root_mean_squared_error: 0.4273 - val_y2_output_root_mean_squared_error: 0.9241
# Epoch 496/500
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4247 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5534
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4222 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5515 - val_loss: 0.9729 - val_y1_output_root_mean_squared_error: 0.4102 - val_y2_output_root_mean_squared_error: 0.9054
# Epoch 497/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4469 - y1_output_root_mean_squared_error: 0.3562 - y2_output_root_mean_squared_error: 0.5599 - val_loss: 1.5144 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 1.1287
# Epoch 498/500
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2867 - y1_output_root_mean_squared_error: 0.2983 - y2_output_root_mean_squared_error: 0.4427
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2910 - y1_output_root_mean_squared_error: 0.3037 - y2_output_root_mean_squared_error: 0.4441 - val_loss: 1.0009 - val_y1_output_root_mean_squared_error: 0.4679 - val_y2_output_root_mean_squared_error: 0.8917
# Epoch 499/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2684 - y1_output_root_mean_squared_error: 0.3112 - y2_output_root_mean_squared_error: 0.4134 - val_loss: 1.1314 - val_y1_output_root_mean_squared_error: 0.5215 - val_y2_output_root_mean_squared_error: 0.9384
# Epoch 500/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3163 - y1_output_root_mean_squared_error: 0.3167 - y2_output_root_mean_squared_error: 0.4547 - val_loss: 1.4640 - val_y1_output_root_mean_squared_error: 0.5072 - val_y2_output_root_mean_squared_error: 1.1133
# Uploading artifacts:   0%|          | 0/11 [00:00<?, ?it/s]
# Uploading artifacts:   0%|          | 0/2 [00:00<?, ?it/s]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5974 - y1_output_root_mean_squared_error: 0.5455 - y2_output_root_mean_squared_error: 1.1365
# Evaluation Results: [1.5110019445419312, 0.5072449445724487, 1.113294243812561]

# %%
# Assuming results has 3 values: total loss, y1_output_rmse, y2_output_rmse
total_loss, y1_rmse, y2_rmse = results
print(f"Total Loss = {total_loss}, Y1 RMSE = {y1_rmse}, Y2 RMSE = {y2_rmse}")
# Out:
# Total Loss = 1.5110019445419312, Y1 RMSE = 0.5072449445724487, Y2 RMSE = 1.113294243812561

# %% [markdown]
# Loss and Metric Over Epochs:

# %%
# Plotting the training and validation loss and metrics (such as RMSE) over epochs helps you see how well your model is learning and if it's overfitting.
def plot_metrics(history, metric_name, title, ylim=None):
    plt.figure()
    plt.title(title)
    if ylim:
        plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.xlabel('Epochs')
    plt.ylabel(metric_name)
    plt.legend()
    plt.show()

plot_metrics(history, 'loss', 'Total Loss', ylim=5)
plot_metrics(history, 'y1_output_root_mean_squared_error', 'Y1 RMSE', ylim=5)
plot_metrics(history, 'y2_output_root_mean_squared_error', 'Y2 RMSE', ylim=5)

# %% [markdown]
# True vs. Predicted Scatter Plot:

# %%
def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    plt.show()

y1_pred, y2_pred = model.predict(norm_test_X)
plot_diff(test_Y['y1_output'], y1_pred, title='Y1: True vs Predicted')
plot_diff(test_Y['y2_output'], y2_pred, title='Y2: True vs Predicted')
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
